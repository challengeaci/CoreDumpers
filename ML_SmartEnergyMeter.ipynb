# %%
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np

data=load_boston()
df=pd.DataFrame(data.data)
df.head(100)


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression




from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer
bot = ChatBot(
    'Techo',
    storage_adapter='chatterbot.storage.SQLStorageAdapter',
    input_adapter='chatterbot.input.TerminalAdapter',
    output_adapter='chatterbot.output.TerminalAdapter',
    logic_adapters=[

        "chatterbot.logic.BestMatch"
    ],
    database='./semdatabase.sqlite3'
)

#conversations = [
 #   'Are you an athlete?', 'No, are you mad? I am a bot',
  #  'Do you like big bang theory?', 'Bazinga!',
   # 'What is my name?', 'Ruan',
    #'What color is the sky?', 'Blue, stop asking me stupid questions'
#]

bot.set_trainer(ListTrainer)
data = open('/home/akaishuichi/Desktop/smartEMeter.txt').read()
main = data.strip().split('\n')
req = data.strip().split(' ')
bot.train(main)
bot.train(req)
# Out:
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%

# %%
while True:
    try:
     open('/home/akaishuichi/Desktop/EMtestout.txt','a+').write(str(bot.get_response(None)))

    except(KeyboardInterrupt, EOFError, SystemExit):
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-26cdcf80bf97> in <module>()
#       1 while True:
#       2     try:
# ----> 3      open('/home/akaishuichi/Desktop/EMtestout.txt','a+').write(str(bot.get_response(None)))
#       4
#       5     except(KeyboardInterrupt, EOFError, SystemExit):
#
# NameError: name 'bot' is not defined
